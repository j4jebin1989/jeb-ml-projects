# %% [markdown]
# # Import Required Libraries
# This section imports essential libraries for data handling and machine learning.

# %%
# Import libraries
import pandas as pd
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Download and Load Iris Dataset
# Load the Iris dataset using scikit-learn and convert it to a pandas DataFrame.

# %%
# Load Iris dataset
iris = datasets.load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# # Create Baseline Notebook File
# This notebook is the baseline for Iris dataset exploration and modeling.

# %% [markdown]
# # Create Source Files for Machine Learning
# Python source files for data processing and model training have been generated in the src directory.

# %%
# Verify Data Loading and File Structure
import os
print('Iris DataFrame shape:', df.shape)
print('baseline notebook exists:', os.path.exists('../notebooks/baseline.ipynb'))
print('src/data.py exists:', os.path.exists('../src/data.py'))
print('src/model.py exists:', os.path.exists('../src/model.py'))
# Out:
# Iris DataFrame shape: (150, 5)
# baseline notebook exists: True
# src/data.py exists: True
# src/model.py exists: True
